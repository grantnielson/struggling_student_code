# %%
### Trying to format with bolds and hyperlinks
import pandas as pd
import smtplib
import ssl
import datetime
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText

# Read data from spreadsheet
data = pd.read_excel('struggling_practice.xlsx')

# convert the startdate column to a datetime object
data['StartDate'] = pd.to_datetime(data['StartDate'])
# convert the startdate column to a string in the format "YYYY-MM-DD"
data['StartDate'] = data['StartDate'].dt.strftime('%Y-%m-%d')


# Define the start of the semester as a datetime object
start_of_semester = datetime.datetime(2023, 1, 9)

# Get the current date as a datetime object
current_date = datetime.datetime.now()

# Calculate the difference between the current date and the start of the semester
delta = current_date - start_of_semester

# Calculate the number of weeks between the two dates
weeks_in = delta.days // 7  # integer division

# Create a secure SSL context
context = ssl.create_default_context()

# Loop over each row in the spreadsheet
for index, row in data.iterrows():
    # Get the parent's name and email
    parent_name = row['GuardianName']
    parent_email = row['Guardian1Email']
###########################  
    #"is current as of (date)"
    start_date = row['StartDate']

    
    # Get the student's name and grade and course
    first_name = row['FirstName']
    last_name = row['LastName']
    student_name = row['StudentName']
    grade = row['CurrentGrade']
    course = row['Name']

    # Create the email message
    msg = MIMEMultipart()
    msg['From'] = 'your_email@example.com'
    msg['To'] = parent_email
    msg['Subject'] = 'Your child\'s grade'
    
    #link and name of link
    link = "https://byuohs.instructure.com/" ##1stiteration:<a href='{link}'>{text}</a>.
    text = "this link"
    link_success = "https://success.byu.edu/high-school"
    text_success = "https://success.byu.edu/high-school"
    
    #emails
    email_ann = "ann_baxter@byu.edu"
    #email_ann_link = https://spartanhoops.com/meeting-mady-the-rim-breaking-big-man-destined-to-steal-your-heart/ #just put it in there w/out shortcut
    
    email_peer_mentor = "peermentoring@byu.edu"
    #email_peer_mentor_link = <a href='mailto:{email_peer_mentor}'>{email_peer_mentor}</a> #just put it in
    
    
    #bold code
    #bold = \033[1m
    #underline = \033[4m
    #italic = \033[3m
   

    # Create the body of the email message
## script: https://byu.app.box.com/integrations/officeonline/openOfficeOnline?fileId=1143192766726&sharedAccessCode=0%2134CLAnE5EK8jEVRNOcojXm50OW1XFok_aA-sQdc-V90hqnbIKLOpxgCYmXiwUoC3SKEwYDERkAU3xuhIHhhdiFMS786zd5LkQLY0-VrATchXsSLKwZ8PfN9h2pZjoI-8zUvwd-mEUCDw5LdUEZ-qPS9Y8JgBZS1iZDlwSc9pCTniz3ERLpCydeDHCFEhB7c8KfzDMrmBr_M.
    body = f"""Dear {first_name} {last_name} and {parent_name},\n\nThe following information from BYU Online High School is current as of {start_date}. 
You are receiving this email due to your student being placed on our watch list for their grades. \n  
\033[3mThe term began {start_date}. We are now {weeks_in} weeks into the term.\033[3m \n 
\033[1mWe would like to make you aware that your student’s grade had dipped below passing in {course}. 
Your current grade is {grade}%.\033[1m In order to see the details please log on to your Canvas account. 
You can access Canvas through <a href='https://byuohs.instructure.com/ '>this link</a>. 
\033[3mThe current grade only includes the assignments that are due or have already been graded. 
Your student's grade will improve as you complete additional assignments.\033[3m 

\033[1mTips for Success and Next Steps: \n\t 1.\033[4m 

Things to Try on Your Own:\033[4m\033[1m \n\t a.      

Create a clear schedule on what needs to be done when to catch up. \n\t b.     

Guardians can set up an observer account in Canvas if they would like access to see student’s grades and work.
To set up an account please reach out to Ann Baxter\033[1m  (\033[4m<a href='mailto:'peermentoring@byu.edu''>peermentoring@byu.edu</a>\033[4m).
\n\t  2.\033[4m 

Reaching out to your teacher:\033[4m\033[1m \n\t a. 

Communicate with the teacher about additional help. \n\t b.  

Here is your teacher's contact information #EMAIL AND OFFICE HOURS MAYBE 
\033[1m\033[4m 3. 
Contact The Student Success Center:\033[4m\033[1m \n\t a. 

Communicate with a Peer Mentor about helping to create a plan to help your student organize their time, develop study skills.
If you do not know which mentor is assigned to your student, please reach out to 
\033[1m(\033[4m<a href='mailto:{email_peer_mentor}'>{email_peer_mentor}</a>\033[4m)\033[4m. \n\t b. 

Schedule an appointment with a free content tutor through the BYU Student Success Center.
You can see tutors and appointment times at\033[1m\033[4m<a href='mailto:{link_success}'>{link_success}</a>.\033[4m)\033[1m""" 
 
    # Attach the body of the email message to the email
    msg.attach(MIMEText(body, 'plain'))

    # Log in to your email account and send the email message
    with smtplib.SMTP_SSL('smtp.gmail.com', 465, context=context) as server:
        server.login('gnielson137@gmail.com', 'wmrenvfbhbmfyfab')
        server.sendmail('gnielson137@gmail.com', parent_email, msg.as_string())

print("Emails sent successfully2.")
    
    
### might need to email to guardianemail2
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-68-e3c56c04ee34> in <module>
#     115     with smtplib.SMTP_SSL('smtp.gmail.com', 465, context=context) as server:
#     116         server.login('gnielson137@gmail.com', 'wmrenvfbhbmfyfab')
# --> 117         server.sendmail('gnielson137@gmail.com', parent_email, msg.as_string())
#     118
#     119 print("Emails sent successfully2.")
#
# ~\Anaconda3\lib\email\message.py in as_string(self, unixfrom, maxheaderlen, policy)
#     156                       maxheaderlen=maxheaderlen,
#     157                       policy=policy)
# --> 158         g.flatten(self, unixfrom=unixfrom)
#     159         return fp.getvalue()
#     160
#
# ~\Anaconda3\lib\email\generator.py in flatten(self, msg, unixfrom, linesep)
#     114                     ufrom = 'From nobody ' + time.ctime(time.time())
#     115                 self.write(ufrom + self._NL)
# --> 116             self._write(msg)
#     117         finally:
#     118             self.policy = old_gen_policy
#
# ~\Anaconda3\lib\email\generator.py in _write(self, msg)
#     197         meth = getattr(msg, '_write_headers', None)
#     198         if meth is None:
# --> 199             self._write_headers(msg)
#     200         else:
#     201             meth(self)
#
# ~\Anaconda3\lib\email\generator.py in _write_headers(self, msg)
#     224     def _write_headers(self, msg):
#     225         for h, v in msg.raw_items():
# --> 226             self.write(self.policy.fold(h, v))
#     227         # A blank line always separates headers from body
#     228         self.write(self._NL)
#
# ~\Anaconda3\lib\email\_policybase.py in fold(self, name, value)
#     324
#     325         """
# --> 326         return self._fold(name, value, sanitize=True)
#     327
#     328     def fold_binary(self, name, value):
#
# ~\Anaconda3\lib\email\_policybase.py in _fold(self, name, value, sanitize)
#     367             if self.max_line_length is not None:
#     368                 maxlinelen = self.max_line_length
# --> 369             parts.append(h.encode(linesep=self.linesep, maxlinelen=maxlinelen))
#     370         parts.append(self.linesep)
#     371         return ''.join(parts)
#
# AttributeError: 'float' object has no attribute 'encode'

# %%
# No Formatting

#____DATE LIST WAS RAN____
#____link____ x2
#make an appointment here {}link 3.a
#3c ____link____
#do we want an email for jennifer chamberlain

import pandas as pd
import smtplib
import ssl
import datetime
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText
from email.mime.image import MIMEImage
import base64

# Read data from spreadsheet
data = pd.read_excel('struggling_practice.xlsx')

# convert the startdate column to a datetime object
data['StartDate'] = pd.to_datetime(data['StartDate'])
# convert the startdate column to a string in the format "YYYY-MM-DD"
data['StartDate'] = data['StartDate'].dt.strftime('%Y-%m-%d')


# Define the start of the semester as a datetime object
start_of_semester = datetime.datetime(2023, 1, 9)

# Get the current date as a datetime object
current_date = datetime.datetime.now()

# Calculate the difference between the current date and the start of the semester
delta = current_date - start_of_semester

# Calculate the number of weeks between the two dates
weeks_in = delta.days // 7  # integer division

# Create a secure SSL context
context = ssl.create_default_context()

# Loop over each row in the spreadsheet
for index, row in data.iterrows():
    # Get the parent's name and email
    parent_name = row['GuardianName']
    parent_email = row['Guardian1Email']
###########################  
    #"is current as of (date)"
    start_date = row['StartDate']

    
    # Get the student's name and grade and course
    first_name = row['FirstName']
    last_name = row['LastName']
    #student_name = row['StudentName']
    grade = row['CurrentGrade']
    course = row['Name']
    letter_grade = row['LetterGrade']

    # Create the email message
    msg = MIMEMultipart()
    msg['From'] = 'your_email@example.com'
    msg['To'] = parent_email
    msg['Subject'] = 'Your child\'s grade'
    
    #link and name of link
    link = "https://byuohs.instructure.com/" ##1stiteration:<a href='{link}'>{text}</a>.
    text = "this link"
    link_success = "https://success.byu.edu/high-school"
    text_success = "https://success.byu.edu/high-school"
    
    #emails
    email_ann = "ann_baxter@byu.edu"
    #email_ann_link = https://spartanhoops.com/meeting-mady-the-rim-breaking-big-man-destined-to-steal-your-heart/ #just put it in there w/out shortcut
    
    email_peer_mentor = "peermentoring@byu.edu"
    #email_peer_mentor_link = <a href='mailto:{email_peer_mentor}'>{email_peer_mentor}</a> #just put it in
    
    
    #bold code
    #bold = \033[1m
    #underline = \033[4m
    #italic = \033[3m
   

    # Create the body of the email message
## script: https://byu.app.box.com/integrations/officeonline/openOfficeOnline?fileId=1143192766726&sharedAccessCode=0%2134CLAnE5EK8jEVRNOcojXm50OW1XFok_aA-sQdc-V90hqnbIKLOpxgCYmXiwUoC3SKEwYDERkAU3xuhIHhhdiFMS786zd5LkQLY0-VrATchXsSLKwZ8PfN9h2pZjoI-8zUvwd-mEUCDw5LdUEZ-qPS9Y8JgBZS1iZDlwSc9pCTniz3ERLpCydeDHCFEhB7c8KfzDMrmBr_M.
    cuerpo = f"""Dear {first_name} {last_name} and {parent_name},\n\nYou are receiving this email as part of the BYU Online High School’s Student Academic Success Program. \n  
The following information is current as of ____DATE LIST WAS RAN____. \n 
The term began {start_date}. We are now {weeks_in} weeks into the term.\n\n
We would like to make you aware that your student’s current grade in {course} is\n\n
\t Letter Grade: {letter_grade}\t\t Percentage: {grade}\n\n
The current grade only includes the assignments that are past due and have already been graded.
Full grade details can be found in your Canvas account at https://byuohs.instructure.com/.\n
In accordance with our Academic Success Program _____link_____, you are now asked to do the following:\n
Letter Grade: C - Your mentor will be emailing you requesting some information, please make sure you
respond.\n
Letter Grade: D/F - Your mentor will be emailing you to set up an appointment, please do so within 7
days. We also ask that you please reach out to your teacher so they can help you.\n\n\n
BYU OHS and the Student Success Center have a number of resources to help you improve your grade.\n\n

\t\t\t~~~~Here are some tips for success~~~\n\n
1. Make a plan. It can sometimes seem overwhelming to get caught up, but the first step is to make a
    plan. Take the time to take an inventory of what needs to be turned in and when. Here is a worksheet
    that will help with that ____link_____.\n
2. Reach out to your teachers. They are here to help you.\n\t
    \tHere is your teacher's contact information _____teacher_email_____.\n
3. Contact the Student Success Center.\n\t 
    \t a. Meet with your mentor. We can set up a homework plan and help hold you accountable. Let’s
        work together to improve your time management and study skills. Make an appointment here
        ___ADD LINK___ or send us an email peermentoring@byu.edu.\n\t 
    \t b.  Guardians can set up an observer account in Canvas if they would like access to see student’s grades and work. \n\t
    \t c.  Check out our Learning Library ____link____ for learning tips and content support. We are adding more content every day.\n
    
4. Keep on top of it. Guardians can set up an observer account in Canvas if they would like access to see
    students’ grades and work. To set up an account please reach out to Jennifer Chamberlain.\n
And finally, Stay positive and believe in yourself. You can do this!!"""
    
    
    ########
        # Read image file and encode it as base64
    with open('BYU_OHS_LOGO.png', 'rb') as f:
        image_data = f.read()
    image_base64 = base64.b64encode(image_data).decode('utf-8')

    
    # Create MIMEText object for cuerpo string
    cuerpo_text = MIMEText(cuerpo, 'plain')
    msg.attach(cuerpo_text)

    # Create HTML body with embedded image
    body = f"""
        <html>
            <body>
                <img src="data:image/png;base64,{image_base64}" />
            </body>
        </html>
    """
    html_body = MIMEText(body, 'html')
    msg.attach(html_body)

    # Attach image to message
    image = MIMEImage(image_data, name='BYU_OHS_LOGO.png')
    image.add_header('Content-ID', '')
    msg.attach(image)
  
    ########
    
    
    # Log in to your email account and send the email message
    with smtplib.SMTP_SSL('smtp.gmail.com', 465, context=context) as server:
        server.login('gnielson137@gmail.com', 'wmrenvfbhbmfyfab')
        server.sendmail('gnielson137@gmail.com', parent_email, msg.as_string())

print("Emails sent successfully")
    
    
############## NEXT STEP: make some test data in the excel file to see if this works! Probably debug as necessary. Then, can show it to supervisor.
## might need to email to guardianemail2
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-c7c114a940cc> in <module>
#     151     with smtplib.SMTP_SSL('smtp.gmail.com', 465, context=context) as server:
#     152         server.login('gnielson137@gmail.com', 'wmrenvfbhbmfyfab')
# --> 153         server.sendmail('gnielson137@gmail.com', parent_email, msg.as_string())
#     154
#     155 print("Emails sent successfully")
#
# ~\Anaconda3\lib\email\message.py in as_string(self, unixfrom, maxheaderlen, policy)
#     156                       maxheaderlen=maxheaderlen,
#     157                       policy=policy)
# --> 158         g.flatten(self, unixfrom=unixfrom)
#     159         return fp.getvalue()
#     160
#
# ~\Anaconda3\lib\email\generator.py in flatten(self, msg, unixfrom, linesep)
#     114                     ufrom = 'From nobody ' + time.ctime(time.time())
#     115                 self.write(ufrom + self._NL)
# --> 116             self._write(msg)
#     117         finally:
#     118             self.policy = old_gen_policy
#
# ~\Anaconda3\lib\email\generator.py in _write(self, msg)
#     197         meth = getattr(msg, '_write_headers', None)
#     198         if meth is None:
# --> 199             self._write_headers(msg)
#     200         else:
#     201             meth(self)
#
# ~\Anaconda3\lib\email\generator.py in _write_headers(self, msg)
#     224     def _write_headers(self, msg):
#     225         for h, v in msg.raw_items():
# --> 226             self.write(self.policy.fold(h, v))
#     227         # A blank line always separates headers from body
#     228         self.write(self._NL)
#
# ~\Anaconda3\lib\email\_policybase.py in fold(self, name, value)
#     324
#     325         """
# --> 326         return self._fold(name, value, sanitize=True)
#     327
#     328     def fold_binary(self, name, value):
#
# ~\Anaconda3\lib\email\_policybase.py in _fold(self, name, value, sanitize)
#     367             if self.max_line_length is not None:
#     368                 maxlinelen = self.max_line_length
# --> 369             parts.append(h.encode(linesep=self.linesep, maxlinelen=maxlinelen))
#     370         parts.append(self.linesep)
#     371         return ''.join(parts)
#
# AttributeError: 'float' object has no attribute 'encode'
